# %%
import cv2
import numpy as np
import os

image_list = os.listdir('C:/Users/abbya/Downloads/pave_intro-main/images/')
length = len(image_list)
hasCircle = [False]*length
center = [None]*length
radius = [None]*length
distance = [None]*length

for n in range(0, length):
    number = str(n)
    filename = 'C:/Users/abbya/Downloads/pave_intro-main/images/lake'+number+'.jpeg'
    image = cv2.imread(filename)
    
    # detect circle from https://www.geeksforgeeks.org/circle-detection-using-opencv-python/
    # Convert to grayscale.
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Apply Hough transform on the  image.
    detected_circles = cv2.HoughCircles(gray,
        cv2.HOUGH_GRADIENT, 1, 20, param1 = 50,
        param2 = 11, minRadius = 1, maxRadius = 400)

    # Draw circles that are detected.
    if detected_circles is not None:
        hasCircle[n] = True

        # Convert the circle parameters a, b and r to integers.
        detected_circles = np.uint16(np.around(detected_circles))

        for pt in detected_circles[0]:
            x, y, r = pt[0], pt[1], pt[2]

            # Center, radius, and distance
            center[n] = [x,y]
            
            radius[n] = r
            
            # assumed using camera similar to GoPro as described here: https://improvephotography.com/54797/gopro-good-enough-for-an-advanced-photographers/#:~:text=Compared%20to%20a%20full%20frame,angle%20can%20be%20a%20limitation. 
            # focal length = 3 mm
            focal_length = 3
            # sensor = 6 × 4 mm  
            # number of pixels = 3000 x 2000  
            # height of pixel = 4 / 2000 = 0.002 mm
            pixel_height = 0.002
            # determine image height
            image_height = (2 * r) * pixel_height
            # most popular circular buoy is 15" by 15" (381 mm by 381 mm)
            object_height = 381
            # using ideal pinhole camera model: image size / object size  =  focal length / distance 
            # want distance in meters
            distance_unrounded = (focal_length * object_height / image_height) / 1000
            distance[n] = round(distance_unrounded, 2)
            
            break # so that only take first circle (best one)
            
            
    print('lake' + number, 'Center:', center[n], 'Radius:', radius[n], 'Distance:', distance[n])
# Out:
# lake0 Center: [602, 718] Radius: 22 Distance: 12.99
# lake1 Center: [1590, 1652] Radius: 128 Distance: 2.23
# lake2 Center: [360, 430] Radius: 9 Distance: 31.75
# lake3 Center: None Radius: None Distance: None
# lake4 Center: [550, 1742] Radius: 141 Distance: 2.03
# lake5 Center: None Radius: None Distance: None
# lake6 Center: None Radius: None Distance: None
# lake7 Center: [2292, 1356] Radius: 86 Distance: 3.32
# lake8 Center: [1294, 1012] Radius: 48 Distance: 5.95
# lake9 Center: None Radius: None Distance: None
# lake10 Center: [2218, 1678] Radius: 130 Distance: 2.2
# lake11 Center: [34, 444] Radius: 10 Distance: 28.58
# lake12 Center: [1072, 1674] Radius: 130 Distance: 2.2
# lake13 Center: [1544, 534] Radius: 12 Distance: 23.81
# lake14 Center: [2278, 1826] Radius: 157 Distance: 1.82
# lake15 Center: [702, 1702] Radius: 135 Distance: 2.12
# lake16 Center: [1808, 820] Radius: 31 Distance: 9.22
# lake17 Center: [2658, 1164] Radius: 63 Distance: 4.54
# lake18 Center: [54, 1718] Radius: 137 Distance: 2.09
# lake19 Center: None Radius: None Distance: None
# lake20 Center: [618, 840] Radius: 33 Distance: 8.66
# lake21 Center: [1752, 1400] Radius: 90 Distance: 3.18
# lake22 Center: [2058, 826] Radius: 32 Distance: 8.93
# lake23 Center: None Radius: None Distance: None
# lake24 Center: None Radius: None Distance: None
# lake25 Center: [1454, 1304] Radius: 80 Distance: 3.57
# lake26 Center: [1536, 810] Radius: 31 Distance: 9.22
# lake27 Center: [432, 1704] Radius: 135 Distance: 2.12
# lake28 Center: [784, 1284] Radius: 77 Distance: 3.71
# lake29 Center: [1026, 1900] Radius: 170 Distance: 1.68
# lake30 Center: None Radius: None Distance: None
# lake31 Center: [2422, 652] Radius: 21 Distance: 13.61
# lake32 Center: [84, 1224] Radius: 70 Distance: 4.08
# lake33 Center: None Radius: None Distance: None
# lake34 Center: [606, 468] Radius: 9 Distance: 31.75
# lake35 Center: [438, 1640] Radius: 125 Distance: 2.29
# lake36 Center: [1966, 1914] Radius: 172 Distance: 1.66
# lake37 Center: [1772, 510] Radius: 11 Distance: 25.98
# lake38 Center: [1236, 1882] Radius: 167 Distance: 1.71
# lake39 Center: [42, 1842] Radius: 154 Distance: 1.86
# lake40 Center: None Radius: None Distance: None
# lake41 Center: [1928, 1970] Radius: 182 Distance: 1.57
# lake42 Center: [650, 476] Radius: 10 Distance: 28.58
# lake43 Center: None Radius: None Distance: None
# lake44 Center: [1060, 1456] Radius: 98 Distance: 2.92
# lake45 Center: [696, 1308] Radius: 80 Distance: 3.57
# lake46 Center: None Radius: None Distance: None
# lake47 Center: None Radius: None Distance: None
# lake48 Center: [16, 1034] Radius: 49 Distance: 5.83
# lake49 Center: [816, 946] Radius: 41 Distance: 6.97
# lake50 Center: [2682, 1352] Radius: 84 Distance: 3.4
# lake51 Center: [754, 1024] Radius: 49 Distance: 5.83
# lake52 Center: [2216, 784] Radius: 29 Distance: 9.85
# lake53 Center: [2644, 1668] Radius: 129 Distance: 2.22
# lake54 Center: [56, 440] Radius: 10 Distance: 28.58
# lake55 Center: None Radius: None Distance: None
# lake56 Center: [1678, 472] Radius: 10 Distance: 28.58
# lake57 Center: [950, 478] Radius: 10 Distance: 28.58
# lake58 Center: [2624, 1008] Radius: 47 Distance: 6.08
# lake59 Center: [2628, 1762] Radius: 144 Distance: 1.98
# lake60 Center: [2004, 1266] Radius: 75 Distance: 3.81
# lake61 Center: [2404, 616] Radius: 17 Distance: 16.81
# lake62 Center: [1794, 1060] Radius: 53 Distance: 5.39
# lake63 Center: None Radius: None Distance: None
# lake64 Center: [254, 888] Radius: 39 Distance: 7.33
# lake65 Center: [1246, 1020] Radius: 48 Distance: 5.95
# lake66 Center: [1960, 1576] Radius: 114 Distance: 2.51
# lake67 Center: [1644, 1136] Radius: 60 Distance: 4.76
# lake68 Center: [2354, 456] Radius: 10 Distance: 28.58
# lake69 Center: [114, 770] Radius: 28 Distance: 10.21
# lake70 Center: [692, 920] Radius: 38 Distance: 7.52
# lake71 Center: [664, 1322] Radius: 80 Distance: 3.57
# lake72 Center: [1778, 732] Radius: 25 Distance: 11.43
# lake73 Center: [2154, 1370] Radius: 89 Distance: 3.21
# lake74 Center: [2588, 1560] Radius: 113 Distance: 2.53
# lake75 Center: [2288, 486] Radius: 11 Distance: 25.98
# lake76 Center: [356, 1722] Radius: 138 Distance: 2.07
# lake77 Center: [234, 1590] Radius: 117 Distance: 2.44
# lake78 Center: [1270, 1186] Radius: 68 Distance: 4.2
# lake79 Center: None Radius: None Distance: None
# lake80 Center: [1132, 644] Radius: 19 Distance: 15.04
# lake81 Center: [394, 1560] Radius: 113 Distance: 2.53
# lake82 Center: None Radius: None Distance: None
# lake83 Center: [344, 1710] Radius: 135 Distance: 2.12
# lake84 Center: None Radius: None Distance: None
# lake85 Center: None Radius: None Distance: None
# lake86 Center: [2218, 1372] Radius: 89 Distance: 3.21
# lake87 Center: None Radius: None Distance: None
# lake88 Center: None Radius: None Distance: None
# lake89 Center: [1938, 1054] Radius: 51 Distance: 5.6
# lake90 Center: [1960, 1224] Radius: 69 Distance: 4.14
# lake91 Center: [2342, 736] Radius: 25 Distance: 11.43
# lake92 Center: [1506, 926] Radius: 41 Distance: 6.97
# lake93 Center: [2212, 1516] Radius: 107 Distance: 2.67
# lake94 Center: [2474, 1764] Radius: 146 Distance: 1.96
# lake95 Center: [622, 1716] Radius: 136 Distance: 2.1
# lake96 Center: [530, 1990] Radius: 183 Distance: 1.56
# lake97 Center: [314, 1988] Radius: 184 Distance: 1.55
# lake98 Center: [352, 1942] Radius: 176 Distance: 1.62
# lake99 Center: None Radius: None Distance: None
